# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path="C:\\Users\\nscda\\Downloads\\MUSHROOM_CLASSIFICATION\\venv\\mushroom_ds\\mushrooms.csv"
md=pd.read_csv(csv_path)

# %%
md.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
md.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
md.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
md.corr
# Out:
# <bound method DataFrame.corr of      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
md.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
md.drop(columns=['cap-shape'], inplace=True)

# %%
md.drop(columns=['gill-attachment'], inplace=True)

# %%
md.drop(columns=['veil-type'], inplace=True)

# %%
md.columns
# Out:
# Index(['class', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-spacing',
#        'gill-size', 'gill-color', 'stalk-shape', 'stalk-root',
#        'stalk-surface-above-ring', 'stalk-surface-below-ring',
#        'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-color',
#        'ring-number', 'ring-type', 'spore-print-color', 'population',
#        'habitat'],
#       dtype='object')

# %%
md.describe()
# Out:
#        class cap-surface cap-color bruises  odor gill-spacing gill-size  \
# count   8124        8124      8124    8124  8124         8124      8124
# unique     2           4        10       2     9            2         2
# top        e           y         n       f     n            c         b
# freq    4208        3244      2284    4748  3528         6812      5612
#
#        gill-color stalk-shape stalk-root stalk-surface-above-ring  \
# count        8124        8124       8124                     8124
# unique         12           2          5                        4
# top             b           t          b                        s
# freq         1728        4608       3776                     5176
#
#        stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# count                      8124                   8124                   8124
# unique                        4                      9                      9
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
y=md['class']
x=md[['cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring','veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']]

# %%
print(x.shape, y.shape)
# Out:
# (8124, 19) (8124,)

# %%
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
y=l.fit_transform(y)
print(y)
# Out:
# [1 0 0 ... 0 1 0]

# %%
x_encoded = x.apply(LabelEncoder().fit_transform)

# %%
x_encoded.head()
# Out:
#    cap-surface  cap-color  bruises  odor  gill-spacing  gill-size  gill-color  \
# 0            2          4        1     6             0          1           4
# 1            2          9        1     0             0          0           4
# 2            2          8        1     3             0          0           5
# 3            3          8        1     6             0          1           5
# 4            2          3        0     5             1          0           4
#
#    stalk-shape  stalk-root  stalk-surface-above-ring  \
# 0            0           3                         2
# 1            0           2                         2
# 2            0           2                         2
# 3            0           3                         2
# 4            1           3                         2
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_encoded,y,test_size=0.3,random_state=73)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((5686, 19), (2438, 19), (5686,), (2438,))

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=200, max_depth=6, class_weight='balanced', random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=6, n_estimators=200,
#                        random_state=42)

# %%
y_pred = model.predict(x_test)

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
print("Default Accuracy:", accuracy)

y_proba = model.predict_proba(x_test)[:, 1]
threshold = 0.3
y_pred_threshold = (y_proba > threshold).astype(int)

print("Confusion Matrix (Adjusted Threshold):")
print(confusion_matrix(y_test, y_pred_threshold))

print("\nClassification Report (Adjusted Threshold):")
print(classification_report(y_test, y_pred_threshold))
# Out:
# Default Accuracy: 0.9967186218211649
# Confusion Matrix (Adjusted Threshold):
# [[1276    0]
#  [   0 1162]]
#
# Classification Report (Adjusted Threshold):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1276
#            1       1.00      1.00      1.00      1162
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
x_encoded['class']=y
correlation_matrix = x_encoded.corr()
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
import pandas as pd
feature_importance = model.feature_importances_
importance_df = pd.DataFrame({'Feature': x_train.columns, 'Importance': feature_importance})
print(importance_df.sort_values(by='Importance', ascending=False))
# Out:
#                      Feature  Importance
# 3                       odor    0.163493
# 6                 gill-color    0.152930
# 5                  gill-size    0.107366
# 16         spore-print-color    0.093522
# 17                population    0.070831
# 15                 ring-type    0.067652
# 8                 stalk-root    0.054072
# 9   stalk-surface-above-ring    0.046469
# 2                    bruises    0.045618
# 10  stalk-surface-below-ring    0.045072
# 4               gill-spacing    0.044763
# 18                   habitat    0.028344
# 7                stalk-shape    0.021578
# 12    stalk-color-below-ring    0.017203
# 1                  cap-color    0.012094
# 11    stalk-color-above-ring    0.011369
# 14               ring-number    0.008880
# 0                cap-surface    0.006712
# 13                veil-color    0.002031

# %%
# Calculate training accuracy
train_accuracy = model.score(x_train, y_train)
print(train_accuracy)


# Calculate test accuracy
test_accuracy = model.score(x_test, y_test)
print(test_accuracy)
# Out:
# 0.995779106577559
# 0.9967186218211649

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Default Accuracy:", accuracy)
# Out:
# Default Accuracy: 0.9967186218211649

# %%
import pickle

# Save the model to a file named 'mushroom_model.pkl'
with open('mushroom_model.pkl', 'wb') as file:
    pickle.dump(model, file)

print("Model saved as mushroom_model.pkl")
# Out:
# Model saved as mushroom_model.pkl
